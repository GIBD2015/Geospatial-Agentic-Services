# %% [markdown]
# # Pennsylvania Hospital Accessibility — Multi-Download Workflow
#
#
# **Real-world question:** *Which Pennsylvania counties are well-served (versus poorly-served) by hospitals within a 10-mile drive band?*

# %% [markdown]
# ## Install GAS Client SDK

# %%
# %pip install -q gas-client

# %% [markdown]
# ## Imports

# %%
from urllib.parse import urljoin
from IPython.display import HTML, Image, display
from gas_client import GasClient

# %% [markdown]
# ## User Settings

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
project_root = Path.cwd()

if project_root.name == "examples_for_using_gas_services":
    project_root = project_root.parent
load_dotenv(project_root / ".env")

server_url = "http://127.0.0.1:4042"
openai_api_key = os.environ["OPENAI_API_KEY"]
census_api_key = os.environ.get("US_CENSUS_API_KEY") 


client = GasClient(
    server_url,
    openai_api_key=openai_api_key,
    artifact_delivery="URL",
)

credentials = {"OPENAI_API_KEY": openai_api_key}
timeout_seconds = 2400

# %% [markdown]
# ## Bind to the Three Agents

# %%
data_agent = client.agent("geospatial_data_retrieval_agent")
vector_agent = client.agent("vector_analysis_agent")
mapping_agent = client.agent("mapping_agent")

for agent in [data_agent, vector_agent, mapping_agent]:
    print(agent.agent_id, agent.status().get("status"))
# Out:
# geospatial_data_retrieval_agent available
# vector_analysis_agent available
# mapping_agent available

# %% [markdown]
# ## Helper Functions

# %%
def absolute_url(url):
    if url.startswith("/"):
        return urljoin(server_url, url)
    return url


def all_artifact_urls(task_result):
    """Return every artifact URL from a (possibly multi-dataset) task response, in order."""
    artifacts = task_result.get("outputs", {}).get("artifacts", []) or []
    urls = [absolute_url(a["url"]) for a in artifacts if a.get("url")]
    return urls


def first_artifact_url(task_result, preferred_extensions=None):
    artifacts = task_result.get("outputs", {}).get("artifacts", []) or []
    preferred_extensions = preferred_extensions or []

    for extension in preferred_extensions:
        for artifact in artifacts:
            url = artifact.get("url")
            filename = artifact.get("filename") or artifact.get("name") or url or ""
            if url and str(filename).lower().endswith(extension.lower()):
                return absolute_url(url)

    for artifact in artifacts:
        if artifact.get("url"):
            return absolute_url(artifact["url"])

    raise RuntimeError("The task returned no artifact URL.")


def pick_url_by_keywords(urls, keywords):
    """Pick the first URL whose filename contains any of the given keywords."""
    for url in urls:
        lower = url.lower()
        if any(k.lower() in lower for k in keywords):
            return url
    return None


def display_visual_artifacts(task_result):
    
    from urllib.request import urlopen

    artifacts = task_result.get("outputs", {}).get("artifacts", []) or []
    for artifact in artifacts:
        url = artifact.get("url")
        filename = artifact.get("filename") or artifact.get("name") or ""
        if not url:
            continue

        display_url = absolute_url(url)
        lower_name = str(filename).lower()
        if lower_name.endswith((".png", ".jpg", ".jpeg", ".gif")):
            image_format = "jpeg" if lower_name.endswith((".jpg", ".jpeg")) else lower_name.rsplit(".", 1)[-1]
            try:
                with urlopen(display_url, timeout=120) as response:
                    image_bytes = response.read()
                # Image(data=...) base64-encodes and stores the bytes in the output,
                # so it survives a push to GitHub and a stopped server.
                display(Image(data=image_bytes, format=image_format))
            except Exception as exc:
                print(f"Could not embed image '{filename}' ({exc}); linking instead.")
                display(HTML(f'<a href="{display_url}" target="_blank">Open image artifact: {filename}</a>'))
        elif lower_name.endswith(".html"):
            display(HTML(f'<a href="{display_url}" target="_blank">Open HTML artifact: {filename}</a>'))
        else:
            display(HTML(f'<a href="{display_url}" target="_blank">Open artifact: {filename}</a>'))


def run_streaming_task(agent, instructions, *, input_datasets=None, title=None):
    if title:
        print("\n" + "=" * 80)
        print(title)
        print("=" * 80)

    final_result = None
    for event in agent.execute_task(
        instructions,
        mode="stream",
        input_datasets=input_datasets,
        artifact_delivery="URL",
        credentials=credentials,
        timeout=timeout_seconds,
    ):
        client.print_stream_event(event)
        if event.get("event") == "task_result":
            final_result = event.get("payload")

    if final_result is None:
        raise RuntimeError("The stream ended before returning a task_result event.")

    client.print_task_summary(final_result)
    return final_result

# %% [markdown]
# ## Step 1: One Retrieval Call → Three Datasets

# %%
multi_retrieval_result = run_streaming_task(
    data_agent,
    (
        "Please download three Pennsylvania datasets:\n"
        "1) Pennsylvania county boundaries from the U.S. Census Bureau TIGER source. "
        "Return a clean GeoPackage with county geometry, GEOID, county name, and STATEFP fields. "
        "Restrict the output strictly to Pennsylvania (STATEFP = 42).\n"
        "2) Pennsylvania hospitals from OpenStreetMap (amenity=hospital and healthcare=hospital). "
        "Return a clean point GeoPackage covering the state of Pennsylvania, with at least name and "
        "the original OSM tags retained where available.\n"
        "3) Pennsylvania major highways from OpenStreetMap (highway=motorway and highway=trunk). "
        "Return a clean line GeoPackage covering the state of Pennsylvania with name and highway-type fields.\n\n"
        "All three datasets should use WGS84 (EPSG:4326). No source API key is required."
    ),
    title="Multi-Dataset Retrieval: PA Counties + Hospitals + Highways",
)
# Out:
# ================================================================================
# Multi-Dataset Retrieval: PA Counties + Hospitals + Highways
# ================================================================================
# [18:47:32] stream_connected: Streaming connection established.
# [18:47:32] Geospatial Data Retrieval Agent: I received your request.
# [18:47:32] Geospatial Data Retrieval Agent: I need to inspect the request text and any provided dataset references before running the agent. I found 0 dataset reference(s).
# [18:47:32] Geospatial Data Retrieval Agent: I found the required credentials and can start the model-backed workflow.
# [18:47:32] task_accepted: Task accepted. Starting streaming execution.
# [18:47:32] Geospatial Data Retrieval Agent: Next I will run the agent with the prepared inputs.
# [18:47:32] Geospatial Data Retrieval Agent: I am checking whether the request asks for one dataset or several.
# [18:47:34] Geospatial Data Retrieval Agent: The request was decomposed into 3 sub-request(s).
# [18:47:34] Geospatial Data Retrieval Agent: I detected 3 datasets in your request. I will download each one as a separate sub-task and return all artifacts.
# [18:47:34] Geospatial Data Retrieval Agent: Starting sub-task 1 of 3: Download Pennsylvania county boundaries from the U.S. Census Bureau TIGER source. Return a clean GeoPackage with county geometry, GEOID, county name, and STATEFP fields, restricted to Pennsylvania (STATEFP = 42) using WGS84 (EPSG:4326).
# [18:47:34] Geospatial Data Retrieval Agent: I will identify the most suitable supported data source, then generate source-specific download logic.
# [18:47:34] Geospatial Data Retrieval Agent: I am comparing the request against the supported data-source handbooks to choose where the dataset should come from.
# [18:47:35] Geospatial Data Retrieval Agent: The source-selection model replied successfully, so I will parse its recommendation.
# [18:47:35] Geospatial Data Retrieval Agent: I selected US Census Bureau boundary as the best available source. Reason: To obtain Pennsylvania county boundaries with attributes such as GEOID, county name, and STATEFP restricted to Pennsylvania (STATEFP = 42), the appropriate data source is 'US Census Bureau boundary' because it provides administrative boundaries at the county level within the United States.
# [18:47:35] Geospatial Data Retrieval Agent: I loaded the US Census Bureau boundary handbook and will use its source-specific download rules.
# [18:47:35] Geospatial Data Retrieval Agent: I am generating a complete Python download program for the selected source and requested dataset.
# [18:47:39] Geospatial Data Retrieval Agent: The code-generation model replied successfully, so I will extract and run the Python program.
# [18:47:39] Geospatial Data Retrieval Agent: I generated the download program and will execute it with automatic repair attempts if the source response or code fails.
# [18:47:39] Geospatial Data Retrieval Agent: I am executing the generated download code (attempt 1 of 10).
# [18:47:39] Geospatial Data Retrieval Agent: The generated code failed on attempt 1 of 10. I will send the error back to the model for a targeted repair.
# [18:47:42] Geospatial Data Retrieval Agent: The model returned a revised download program; I will retry execution.
# [18:47:42] Geospatial Data Retrieval Agent: I am executing the generated download code (attempt 2 of 10).
# [18:47:42] Geospatial Data Retrieval Agent: The generated download code executed successfully.
# [18:47:42] Geospatial Data Retrieval Agent: I created 67 records and packaged 1 artifact(s) for the final response.
# [18:47:42] Geospatial Data Retrieval Agent: I am writing the final summary to explain what was downloaded and what the dataset contains.
# [18:47:44] Geospatial Data Retrieval Agent: I validated the output artifact before returning it. Validation status: passed.
# [18:47:44] Geospatial Data Retrieval Agent: Starting sub-task 2 of 3: Download Pennsylvania hospitals from OpenStreetMap (amenity=hospital and healthcare=hospital). Return a clean point GeoPackage covering the state of Pennsylvania, with at least name and the original OSM tags retained where available, using WGS84 (EPSG:4326).
# [18:47:44] Geospatial Data Retrieval Agent: I will identify the most suitable supported data source, then generate source-specific download logic.
# [18:47:44] Geospatial Data Retrieval Agent: I am comparing the request against the supported data-source handbooks to choose where the dataset should come from.
# [18:47:45] Geospatial Data Retrieval Agent: The source-selection model replied successfully, so I will parse its recommendation.
# [18:47:45] Geospatial Data Retrieval Agent: I selected OpenStreetMap as the best available source. Reason: Since the task requires downloading Pennsylvania hospitals (amenity=hospital and healthcare=hospital) and retaining original OSM tags from OpenStreetMap, I should download data from OpenStreetMap.
# [18:47:45] Geospatial Data Retrieval Agent: I loaded the OpenStreetMap handbook and will use its source-specific download rules.
# [18:47:45] Geospatial Data Retrieval Agent: I am generating a complete Python download program for the selected source and requested dataset.
# [18:47:50] Geospatial Data Retrieval Agent: The code-generation model replied successfully, so I will extract and run the Python program.
# [18:47:50] Geospatial Data Retrieval Agent: I generated the download program and will execute it with automatic repair attempts if the source response or code fails.
# [18:47:50] Geospatial Data Retrieval Agent: I am executing the generated download code (attempt 1 of 10).
# [18:48:00] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:48:10] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:48:20] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:48:30] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:48:40] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:48:50] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:49:00] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:49:10] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:49:17] Geospatial Data Retrieval Agent: The generated download code executed successfully.
# [18:49:17] Geospatial Data Retrieval Agent: I created 41 records and packaged 1 artifact(s) for the final response.
# [18:49:17] Geospatial Data Retrieval Agent: I am writing the final summary to explain what was downloaded and what the dataset contains.
# [18:49:22] Geospatial Data Retrieval Agent: I validated the output artifact before returning it. Validation status: failed.
# [18:49:22] Geospatial Data Retrieval Agent: Starting sub-task 3 of 3: Download Pennsylvania major highways from OpenStreetMap (highway=motorway and highway=trunk). Return a clean line GeoPackage covering the state of Pennsylvania with name and highway-type fields, using WGS84 (EPSG:4326).
# [18:49:22] Geospatial Data Retrieval Agent: I will identify the most suitable supported data source, then generate source-specific download logic.
# [18:49:22] Geospatial Data Retrieval Agent: I am comparing the request against the supported data-source handbooks to choose where the dataset should come from.
# [18:49:23] Geospatial Data Retrieval Agent: The source-selection model replied successfully, so I will parse its recommendation.
# [18:49:23] Geospatial Data Retrieval Agent: I selected OpenStreetMap as the best available source. Reason: To download Pennsylvania major highways with highway types motorway and trunk, I should use OpenStreetMap, as it provides street networks and allows filtering by highway types.
# [18:49:23] Geospatial Data Retrieval Agent: I loaded the OpenStreetMap handbook and will use its source-specific download rules.
# [18:49:23] Geospatial Data Retrieval Agent: I am generating a complete Python download program for the selected source and requested dataset.
# [18:49:29] Geospatial Data Retrieval Agent: The code-generation model replied successfully, so I will extract and run the Python program.
# [18:49:29] Geospatial Data Retrieval Agent: I generated the download program and will execute it with automatic repair attempts if the source response or code fails.
# [18:49:29] Geospatial Data Retrieval Agent: I am executing the generated download code (attempt 1 of 10).
# [18:49:39] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:49:49] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:49:59] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:50:09] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:50:19] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:50:29] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:50:39] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:50:49] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:50:55] Geospatial Data Retrieval Agent: The generated code failed on attempt 1 of 10. I will send the error back to the model for a targeted repair.
# [18:51:03] Geospatial Data Retrieval Agent: The model returned a revised download program; I will retry execution.
# [18:51:03] Geospatial Data Retrieval Agent: I am executing the generated download code (attempt 2 of 10).
# [18:51:13] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:51:23] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:51:33] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:51:43] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:51:53] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:52:03] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:52:13] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:52:23] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:52:33] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:52:44] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:52:54] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:53:04] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:53:14] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:53:24] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:53:34] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:53:44] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:53:54] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:54:04] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:54:14] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:54:24] Geospatial Data Retrieval Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:54:32] Geospatial Data Retrieval Agent: The generated download code executed successfully.
# [18:54:32] Geospatial Data Retrieval Agent: I created 27,359 records and packaged 1 artifact(s) for the final response.
# [18:54:32] Geospatial Data Retrieval Agent: I am writing the final summary to explain what was downloaded and what the dataset contains.
# [18:54:34] Geospatial Data Retrieval Agent: I validated the output artifact before returning it. Validation status: failed.
# [18:54:34] Geospatial Data Retrieval Agent: All sub-tasks finished. 3 succeeded, 0 failed, 3 artifact(s) packaged.
# [18:54:34] Geospatial Data Retrieval Agent: The agent finished its workflow, so I will normalize the result and prepare artifacts.
# [18:54:34] task_succeeded: Task finished.
# [18:54:34] task_result: final task received e1dccd71-f17c-4948-b1d6-35693080a8d1
#
# ========================================================================
# GAS Task Summary
# ========================================================================
# Task         : e1dccd71-f17c-4948-b1d6-35693080a8d1
# Status       : successful
# Agent        : Geospatial Data Retrieval Agent
# Version      : 1.0.0
# Model        : gpt-4o
# Duration     : 421.46s
# Iterations   : 12
#
# Usage
# -----
# LLM calls    : 12
# Tool calls   : 0
# Input tokens : 19,371
# Output tokens: 3,215
# Total tokens : 22,586
#
# Outputs
# -------
# Summary      : Multi-dataset retrieval: 3 of 3 sub-requests produced artifacts (0 failed). Total artifacts: 3.
# Artifacts    : 3
#   1. geospatial_data_retrieval_agent-4578-qoke-2599.gpkg
#      type=downloadable_file format=gpkg size=446,464 bytes
#      url=http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-4578-qoke-2599.gpkg
#   2. geospatial_data_retrieval_agent-5041-fnov-2509.gpkg
#      type=downloadable_file format=gpkg size=110,592 bytes
#      url=http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-5041-fnov-2509.gpkg
#   3. geospatial_data_retrieval_agent-4428-qgwe-5686.gpkg
#      type=downloadable_file format=gpkg size=7,954,432 bytes
#      url=http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-4428-qgwe-5686.gpkg
#
# Diagnostics
# -----------
# Has error    : 0
# Warnings     : -
# ========================================================================

# %% [markdown]
# ### Inspect the Multi-Download Response

# %%
metrics = multi_retrieval_result.get("metrics", {})
print("sub_task_count       :", metrics.get("sub_task_count"))
print("successful_sub_tasks :", metrics.get("successful_sub_tasks"))
print("failed_sub_tasks     :", metrics.get("failed_sub_tasks"))
print("total artifacts      :", metrics.get("number_of_artifacts"))

downloaded_urls = all_artifact_urls(multi_retrieval_result)
for url in downloaded_urls:
    print("  -", url)
# Out:
# sub_task_count       : None
# successful_sub_tasks : None
# failed_sub_tasks     : None
# total artifacts      : None
#   - http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-4578-qoke-2599.gpkg
#   - http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-5041-fnov-2509.gpkg
#   - http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-4428-qgwe-5686.gpkg

# %%
downloaded_urls = all_artifact_urls(multi_retrieval_result)
if len(downloaded_urls) < 3:
    raise RuntimeError(
        f"Expected 3 downloaded artifacts (counties, hospitals, highways) but got {len(downloaded_urls)}. "
        "Inspect the multi-retrieval task output above before proceeding.\n"
        f"Artifacts: {downloaded_urls}"
    )

counties_url, hospitals_url, highways_url = downloaded_urls[0], downloaded_urls[1], downloaded_urls[2]

print("counties :", counties_url)
print("hospitals:", hospitals_url)
print("highways :", highways_url)

sub_tasks = multi_retrieval_result.get("outputs", {}).get("sub_tasks", []) or []
if sub_tasks:
    print("\nSub-task breakdown (verify the request-to-artifact mapping):")
    for record in sub_tasks:
        req_preview = (record.get("sub_request") or "")[:90]
        print(
            f"  #{record.get('sub_request_index')} "
            f"({record.get('artifact_count')} artifact(s)): "
            f"{req_preview}..."
        )
# Out:
# counties : http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-4578-qoke-2599.gpkg
# hospitals: http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-5041-fnov-2509.gpkg
# highways : http://127.0.0.1:4042/agents/geospatial_data_retrieval_agent/data/geospatial_data_retrieval_agent-4428-qgwe-5686.gpkg

# %% [markdown]
# ## Step 2: Compute 10-Mile Hospital Coverage Per County

# %%
coverage_result = run_streaming_task(
    vector_agent,
    (
        "Compute hospital accessibility per Pennsylvania county using the provided layers. "
        "Inputs (in this order): (1) PA county polygons, (2) PA hospital points, (3) PA highways (not used in the analysis, ignore). "
        "Steps: "
        "a) Reproject counties and hospitals to EPSG:5070 (NAD83 Conus Albers, units = meters) for buffering and area math. "
        "b) Buffer each hospital point by 16093 meters (10 miles) and dissolve all buffers into one coverage polygon. "
        "c) Intersect the dissolved coverage with each county; compute covered_area_m2 per county (0 if no overlap). "
        "d) Compute county_area_m2 from the projected county geometry and a new numeric field "
        "   coverage_pct = covered_area_m2 / county_area_m2 * 100, clamped to [0, 100]. "
        "e) Reproject the result back to EPSG:4326. "
        "Return one GeoPackage of PA counties with original identifiers (GEOID, NAME) and the new "
        "coverage_pct field. Do not return the hospital or highway layers from this step."
    ),
    input_datasets=[counties_url, hospitals_url, highways_url],
    title="Compute 10-mile Hospital Coverage per PA County",
)

coverage_url = first_artifact_url(
    coverage_result, preferred_extensions=[".gpkg", ".geojson", ".json"]
)
coverage_url
# Out:
# ================================================================================
# Compute 10-mile Hospital Coverage per PA County
# ================================================================================
# [18:55:31] stream_connected: Streaming connection established.
# [18:55:31] Vector Analysis Agent: I received your request.
# [18:55:32] Vector Analysis Agent: I need to inspect the request text and any provided dataset references before running the agent. I found 3 dataset reference(s).
# [18:55:32] Vector Analysis Agent: I found the required credentials and can start the model-backed workflow.
# [18:55:32] task_accepted: Task accepted. Starting streaming execution.
# [18:55:32] Vector Analysis Agent: Next I will run the agent with the prepared inputs.
# [18:55:32] Vector Analysis Agent: I will load the requested vector/tabular inputs, run code-driven analysis, and save a final dataset artifact from 3 dataset reference(s).
# [18:55:32] Vector Analysis Agent: I detected a common vector operation and will first try a deterministic GeoPandas workflow.
# [18:55:32] Vector Analysis Agent: Added geometry measurement field(s): area_sq_m, area_sq_km and saved 67 feature(s) as GeoPackage.
# [18:55:32] Vector Analysis Agent: I saved the deterministic vector analysis result with 67 record(s).
# [18:55:32] Vector Analysis Agent: The agent finished its workflow, so I will normalize the result and prepare artifacts.
# [18:55:33] task_succeeded: Task finished.
# [18:55:33] task_result: final task received fd47bcdd-e3e7-4591-9ab5-a26556a57ccd
#
# ========================================================================
# GAS Task Summary
# ========================================================================
# Task         : fd47bcdd-e3e7-4591-9ab5-a26556a57ccd
# Status       : successful
# Agent        : Vector Analysis Agent
# Version      : 2.1.0
# Model        : deterministic
# Duration     : 0.42s
# Iterations   : 0
#
# Usage
# -----
# LLM calls    : 0
# Tool calls   : 0
# Input tokens : 0
# Output tokens: 0
# Total tokens : 0
#
# Outputs
# -------
# Summary      : Added geometry measurement field(s): area_sq_m, area_sq_km and saved 67 feature(s) as GeoPackage.
# Artifacts    : 1
#   1. vector_analysis_agent-0924-qapg-7517.gpkg
#      type=downloadable_file format=gpkg size=450,560 bytes
#      url=http://127.0.0.1:4042/agents/vector_analysis_agent/data/vector_analysis_agent-0924-qapg-7517.gpkg
#
# Diagnostics
# -----------
# Has error    : 0
# Warnings     : -
# ========================================================================
# 'http://127.0.0.1:4042/agents/vector_analysis_agent/data/vector_analysis_agent-0924-qapg-7517.gpkg'

# %% [markdown]
# ## Step 3: Map the Result
#
# The mapping agent renders the choropleth of `coverage_pct` with hospitals and major highways overlaid for context.

# %%
map_result = run_streaming_task(
    mapping_agent,
    (
        "Create a professional county-level choropleth map of Pennsylvania showing 10-mile hospital coverage. "
        "Inputs (in this order): (1) PA counties with a coverage_pct field, (2) PA hospital points, "
        "(3) PA major highways. "
        "Use coverage_pct for county fill color, a 5-class sequential green color ramp (light = low coverage, "
        "dark = high coverage), thin dark-gray county outlines, hospital points as small red dots on top, "
        "and highways as semi-transparent dark gray lines beneath the hospital points. "
        "Use the EPSG:5070 (Conus Albers) projection, a legend outside the map area listing the choropleth "
        "breaks and a small inset legend for hospitals and highways, the title "
        "'Pennsylvania Counties: % Area Within 10 Miles of a Hospital', and a small data-source caption "
        "crediting OpenStreetMap and U.S. Census TIGER."
    ),
    input_datasets=[coverage_url, hospitals_url, highways_url],
    title="Render the PA Hospital Coverage Map",
)
# Out:
# ================================================================================
# Render the PA Hospital Coverage Map
# ================================================================================
# [18:56:05] stream_connected: Streaming connection established.
# [18:56:05] Mapping Agent: I received your request.
# [18:56:05] Mapping Agent: I need to inspect the request text and any provided dataset references before running the agent. I found 3 dataset reference(s).
# [18:56:05] Mapping Agent: I found the required credentials and can start the model-backed workflow.
# [18:56:05] task_accepted: Task accepted. Starting streaming execution.
# [18:56:06] Mapping Agent: Next I will run the agent with the prepared inputs.
# [18:56:06] Mapping Agent: I will inspect the requested visualization and the 3 dataset reference(s), then choose whether a map or chart is the best way to answer it.
# [18:56:06] Mapping Agent: I am drafting visualization code now. This is attempt 1; I will run the code and check whether it creates the requested output correctly.
# [18:56:16] Mapping Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:56:26] Mapping Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:56:34] Mapping Agent: The generated code did not run correctly because ValueError: County dataset must include 'coverage_pct' for choropleth mapping.. I will use this error feedback to revise the code and try again.
# [18:56:34] Mapping Agent: I am drafting visualization code now. This is attempt 2; I will run the code and check whether it creates the requested output correctly.
# [18:56:44] Mapping Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:56:54] Mapping Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:57:04] Mapping Agent: I'm still working. Long LLM calls, code execution, or geospatial file processing can take a little while.
# [18:57:05] Mapping Agent: The generated code ran successfully on attempt 2. I found the output artifact and can now prepare the final map response.
# [18:57:05] Mapping Agent: The mapping workflow is complete. I am packaging the generated visualization, summary, and supporting metadata for the final response.
# [18:57:05] Mapping Agent: The agent finished its workflow, so I will normalize the result and prepare artifacts.
# [18:57:05] task_succeeded: Task finished.
# [18:57:06] task_result: final task received 610239b3-fd3a-4849-ab20-55565cdd6f85
#
# ========================================================================
# GAS Task Summary
# ========================================================================
# Task         : 610239b3-fd3a-4849-ab20-55565cdd6f85
# Status       : successful
# Agent        : Mapping Agent
# Version      : 2.0.1
# Model        : gpt-5.4
# Duration     : 59.59s
# Iterations   : 2
#
# Usage
# -----
# LLM calls    : 2
# Tool calls   : 2
# Input tokens : 17,613
# Output tokens: 4,374
# Total tokens : 21,987
#
# Outputs
# -------
# Summary      : Successfully generated visualization in 2 iterations.
# Artifacts    : 1
#   1. mapping_agent-1561-usfo-7873.png
#      type=downloadable_file format=png size=755,638 bytes
#      url=http://127.0.0.1:4042/agents/mapping_agent/data/mapping_agent-1561-usfo-7873.png
#
# Diagnostics
# -----------
# Has error    : 0
# Warnings     : -
# ========================================================================

# %%
display_visual_artifacts(map_result)
